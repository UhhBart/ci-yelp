# %% [markdown]
# <H1> Content based filtering</H1>
# <H3> Iris Bakker en Bart van den Broek</H3>

# %% [markdown]
# <H2>Import and load data</H2>

# %%
from pandas import Series, Timestamp
import pandas as pd
from pandas import DataFrame
import numpy as np
import simplejson as json
import matplotlib.pyplot as plt

# %%
def load_jsons(data_path, file):
    """ helper function to load '.json' files (they're not proper jsons) """
    file_path = data_path + file
    with open(file_path) as jsons:
        lines = [json.loads(json_line) for json_line in jsons]
    return pd.DataFrame(lines)

# %% [markdown]
# <H2> Load json files as Df</H2>

# %%
# Load data for town called Ambridge
data_path = '../data/ambridge/'

# Seperate the files 
review_file = 'review.json'
business_file = 'business.json'
user_file = 'user.json'
tip_file = 'tip.json'
checkin_file = 'checkin.json'

reviews = load_jsons(data_path, review_file)
businesses = load_jsons(data_path, business_file)
users = load_jsons(data_path, user_file)
tips = load_jsons(data_path, tip_file)
checkins = load_jsons(data_path, checkin_file)

# %% [markdown]
# <H3> Display dataframe with useful columns</H3>

# %%
# Displays the reviews, high star ratings first
highest_stars = (reviews.sort_values(by='stars', ascending=False))
display(personal_stars)

# Displays the columns we will actually need in this assignment
cat = highest_stars[['user_id','business_id', 'stars', 'review_id']]
cat['categories'] = businesses['categories']
display(cat)
# Out:
#                   review_id                 user_id             business_id  \
# 126  wVKQ1qZssiWnGPJqLnjUBg  gFZpRY97hKb2Oeffjo8dvg  fDQF6ojXgCZsqaqQkrQvdQ
# 58   iBFirpfG2ONoV8FoaQrRvg  RlSZhAJCkYbyMkvjljeLeQ  fDQF6ojXgCZsqaqQkrQvdQ
# 166  i2kDaW9br-dDgi5x7-GKQQ  Gk5xfuVdsIOHNo_vfoHELg  fDQF6ojXgCZsqaqQkrQvdQ
# 162  XaFWZiVeVpRCYsvqF2HPtQ  ETOxL8gIBIIASEiyT0DJkg  fDQF6ojXgCZsqaqQkrQvdQ
# 142  pVTq7BhsunUxpvVm6Om0XA  S3d7GcXk90qI8IyOmbMT3A  fDQF6ojXgCZsqaqQkrQvdQ
# ..                      ...                     ...                     ...
# 43   Hi35lcHVBQ23NDbye_kYEQ  1hkzLE-HBuAlPIbk7Ob9Rw  fDQF6ojXgCZsqaqQkrQvdQ
# 191  gEXVHGcbpXoZXFdIof3gQg  NCKuhe47yqcMQ_v-kQPmzA  fDQF6ojXgCZsqaqQkrQvdQ
# 229  M58oQEaXfOHv2I-GimqEHA  nLrfvJnDAK4C0KMr5PwiGA  fDQF6ojXgCZsqaqQkrQvdQ
# 137  luspYqrc4GxwoUYjwjPTRA  Yo0ZBgaphTWeWETiVT03kQ  fDQF6ojXgCZsqaqQkrQvdQ
# 224  BXOAUlnpStEptdkPAgAZzg  dHxSyJeJmF7uNg_5p72hHA  fDQF6ojXgCZsqaqQkrQvdQ
#
#      stars  useful  funny  cool  \
# 126    5.0       0      1     0
# 58     5.0       0      0     0
# 166    5.0       2      1     1
# 162    5.0       0      0     0
# 142    5.0       0      0     0
# ..     ...     ...    ...   ...
# 43     1.0       0      0     0
# 191    1.0       0      0     0
# 229    1.0       0      0     0
# 137    1.0       0      0     0
# 224    1.0       0      0     0
#
#                                                   text                 date
# 126  Best Burger probably EVER! Although get ready ...  2018-07-30 16:15:23
# 58   Not knowing exactly what to expect we walked i...  2016-10-03 18:19:43
# 166  A rare occasion for me to visit a restaurant o...  2016-05-25 02:48:11
# 162  This place was amazing the burgers were mouth-...  2018-08-11 20:38:43
# 142  This place has the best burgers in town! Our s...  2017-08-15 19:59:08
# ..                                                 ...                  ...
# 43   No gluten free buns!!?? Really, even cheap bur...  2017-02-11 21:48:37
# 191  I came here with my husband for dinner on our ...  2016-09-04 03:01:21
# 229  Wow, this place is bad!!! We grabbed a quick d...  2017-04-18 23:17:11
# 137  Disappointing; not the same. I have eaten here...  2016-12-29 13:29:22
# 224  gee i was shocked to see they want 7.00 for a ...  2016-05-03 04:18:50
#
# [253 rows x 9 columns]
# C:\Users\irisb\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                     user_id             business_id  stars  \
# 0    hXydWH25S92HjI5hmWRSyA  dJ0R-XT78LUQeNHQkD-G9g    5.0
# 206  g08bkzhvjsST-0g2TfEg7Q  N92Pbr2ygKDLkjmr-4BAPw    5.0
# 220  wFFLWorAWh3hpxVLQP8YWw  N92Pbr2ygKDLkjmr-4BAPw    5.0
# 219  sy_uis3d_sgIGodPZktQcQ  N92Pbr2ygKDLkjmr-4BAPw    5.0
# 216  QNecf-DovpR9IVq1z1YJbw  N92Pbr2ygKDLkjmr-4BAPw    5.0
# ..                      ...                     ...    ...
# 172  gB8hGkSEUT5n6VPGHXYjbA  pcbVl6ZHDOJHsnetY0rJEQ    1.0
# 89   NOR93THAvtPUrJlzP9a3pA  ftx72aqADrNYmOlMytdtCg    1.0
# 243  1gJw6DxTrf0Zmp9gDgYlrQ  LHd0Y_0tIWWPvRqDb2b74Q    1.0
# 168  Uz51g_KgDx7nHyHD2OXZLA  EZ9zSk4ld27LwgfANoF4VA    1.0
# 188  VENurDsqZxxtSxlQBN5i0w  N92Pbr2ygKDLkjmr-4BAPw    1.0
#
#                   review_id                       categories
# 0    qb2EVdmVNvw3D0kBMN6Xrg  Food, Ice Cream & Frozen Yogurt
# 206  js_s0o390gbWyuLomlJifw                              NaN
# 220  YuLDKmcoYoDOFPgAWm9L1A                              NaN
# 219  7GycrjM2XnmWnpSEFhOTTA                              NaN
# 216  8odAO3gLebrJsJKi7VaWHA                              NaN
# ..                      ...                              ...
# 172  D8TncjqEjGfcKTeBMomJag                              NaN
# 89   PlMDL03wlb59DW0C34hvdg                              NaN
# 243  MWagIb1mqD80k1_G8GDZ2g                              NaN
# 168  6h88DqBbwtJRhbeGOj4lvQ                              NaN
# 188  ktOYRsQpzA_DQFni-R7Ynw                              NaN
#
# [379 rows x 5 columns]

# %% [markdown]
# <H1>HALLO</H1>
# Vanaf hier wil ik dus eigenlijk verder gaan met het dataframe 'cat' en het volgende doen:
#
# 1. Cats namaken maar dan gebaseerd op één gebruiker
# 2. Je kijkt naar de hoogste stars van de gebruiker, deze selecteer je (bijvoorbeeld alles van 3 t/m 5 stars)
# 3. Je kijkt naar welke categorieën bij deze hoogste stars horen
# 4. Deze categorieën vergelijk je met anderen (similarity dus)
# 5. Je koppelt de categorie die waarschijnlijk leuk gevonden wordt terug aan een bedrijf
# 6. Je raadt de gebruiker het bedrijf aan
#
#
# <H1>VOORBEELD</H1>
# Iris heeft 3 reviews gegeven en we willen weten of restaurant ABC iets voor haar is
#
# 1. In Iris tabel zien we dat de hoogste reviews zijn gegeven in CATS(4 stars) en in DOGS(5 stars)
# 2. Restaurant CATS heeft de categorie kindvriendelijk restaurant DOGS heeft de categorie ijsjes
# 3. Kindvriendelijk en ijsjes krijgen allebei een hoge rating en zijn dus similar
# 4. Restaurant ABC heeft als categorie ijsjes
# 5. Restaurant ABC wordt aangeraden aan Iris, omdat ijsjes eerder een categorie was met een hoge rating
#
# Dit kun je natuurlijk uitbreiden naar andere gebruikers erin betrekken, die dezelfde categorieën als Iris hoge ratings geven en ook meer bedrijven hebben uitgetest.
#
# <H1> KLOPT DIT OF IS DIT NIET CONTENT BASED?!?! </H1>

# %%
"""
All these functions were taken and modified from module 3
"""

def extract_categories(businesses):
    categories = businesses.apply(lambda row: pd.Series([row['categories']] + row['business_id'].lower().split(",")), axis=1)
    stack_categories = categories.set_index(0).stack()
    df_stack_categories = stack_categories.to_frame()
    df_stack_categories['business_id'] = stack_categories.index.droplevel(1)
    df_stack_categories.columns = ['category', 'business_id']
    return df_stack_categories.reset_index()[['business_id', 'category']]

def pivot_categories(df):
    """Create a one-hot encoded matrix for categories.
    
    Arguments:
    df -- a dataFrame containing at least the columns 'businessId' and 'category'
    
    Output:
    a matrix containing '0' or '1' in each cell.
    1: the business has the category
    0: the business does not have the category
    """
    return df.pivot_table(index = 'business_id', columns = 'category', aggfunc = 'size', fill_value=0)

def create_similarity_matrix_jaccard(matrix):
    m11 = matrix @ matrix.T
    m10 = pd.DataFrame(matrix.sum(axis = 1).values + np.zeros(m11.shape), index = m11.index, columns = m11.index)
    m01 = m10.T
    return m11/(m01 + m10 - m11)

categories = extract_categories(businesses)
df_utility_categories = pivot_categories(categories)
similarity_matrix_categories = create_similarity_matrix_jaccard(df_utility_categories)

# %%
# Shows 1 when category is given to the business, 0 if not
display(pivot_categories(categories.head()))
# Out:
# category                                            3gl18exylqutlzqb6tmb0w  \
# business_id
# Auto Repair, Smog Check Stations, Tires, Automo...                       1
# Breakfast & Brunch, Restaurants, American (Trad...                       0
# Filipino, Food, Restaurants, Barbeque, Smokehouse                        0
# Florists, Flowers & Gifts, Shopping                                      0
# Food, Ice Cream & Frozen Yogurt                                          0
#
# category                                            dj0r-xt78luqenhqkd-g9g  \
# business_id
# Auto Repair, Smog Check Stations, Tires, Automo...                       0
# Breakfast & Brunch, Restaurants, American (Trad...                       0
# Filipino, Food, Restaurants, Barbeque, Smokehouse                        0
# Florists, Flowers & Gifts, Shopping                                      0
# Food, Ice Cream & Frozen Yogurt                                          1
#
# category                                            eu_zptrnvaxkpdsxf7cj2w  \
# business_id
# Auto Repair, Smog Check Stations, Tires, Automo...                       0
# Breakfast & Brunch, Restaurants, American (Trad...                       1
# Filipino, Food, Restaurants, Barbeque, Smokehouse                        0
# Florists, Flowers & Gifts, Shopping                                      0
# Food, Ice Cream & Frozen Yogurt                                          0
#
# category                                            q_0egl-aelqhkukhvmldwa  \
# business_id
# Auto Repair, Smog Check Stations, Tires, Automo...                       0
# Breakfast & Brunch, Restaurants, American (Trad...                       0
# Filipino, Food, Restaurants, Barbeque, Smokehouse                        1
# Florists, Flowers & Gifts, Shopping                                      0
# Food, Ice Cream & Frozen Yogurt                                          0
#
# category                                            yjf0i2j9q52dyit8uvgt3g
# business_id
# Auto Repair, Smog Check Stations, Tires, Automo...                       0
# Breakfast & Brunch, Restaurants, American (Trad...                       0
# Filipino, Food, Restaurants, Barbeque, Smokehouse                        0
# Florists, Flowers & Gifts, Shopping                                      1
# Food, Ice Cream & Frozen Yogurt                                          0

# %%
display(similarity_matrix_categories.head())
# Out:
# business_id             -InU2nAbC9AuS-Um2Cowgw  0EyRe-VkW8gYxxZ7NCQXeQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     1.0                0.000000
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                1.000000
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                0.166667
# 3gL18eXylqutlzqb6TmB0w                     0.0                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                0.166667
#
# business_id             2_7lYF6P2cYKnSiPhhVyPQ  3gL18eXylqutlzqb6TmB0w  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.166667                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                1.000000                     0.0
# 3gL18eXylqutlzqb6TmB0w                0.000000                     1.0
# 4mpSNvmyG89Uqy2ahP4JMQ                0.142857                     0.0
#
# business_id             4mpSNvmyG89Uqy2ahP4JMQ  729grSa1Wsn-hfv7D5uOxg  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                    0.20
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.166667                    0.25
# 2_7lYF6P2cYKnSiPhhVyPQ                0.142857                    0.00
# 3gL18eXylqutlzqb6TmB0w                0.000000                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                1.000000                    0.00
#
# business_id             7xRbOtZUuw7DxOWrHeaanw  EOmRHPvzR88a5R2j2uD0cQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.200000                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                0.166667                     0.0
# 3gL18eXylqutlzqb6TmB0w                0.000000                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                0.166667                     0.0
#
# business_id             EZ9zSk4ld27LwgfANoF4VA  Eu_zPTrNVAXkpdSxf7CJ2w  ...  \
# business_id                                                             ...
# -InU2nAbC9AuS-Um2Cowgw                     0.0                0.000000  ...
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                0.200000  ...
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                0.166667  ...
# 3gL18eXylqutlzqb6TmB0w                     0.0                0.000000  ...
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                0.166667  ...
#
# business_id             lawYwEXAE-Sq2nf6co7aBg  muFJIZKZwbAfy_pEFKF_pw  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                    0.00
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.000000                    0.25
# 2_7lYF6P2cYKnSiPhhVyPQ                0.166667                    0.20
# 3gL18eXylqutlzqb6TmB0w                0.000000                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                0.000000                    0.20
#
# business_id             pcbVl6ZHDOJHsnetY0rJEQ  rdHO0LkiNe6s3716hPuQXQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                0.000000
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                0.166667
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                0.600000
# 3gL18eXylqutlzqb6TmB0w                     0.0                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                0.142857
#
# business_id             tTDxa8OzmxUkpVifQ-cEWw  t_EiW3FlMnFTHyoeVU79xg  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                    0.00                    0.25
# 0EyRe-VkW8gYxxZ7NCQXeQ                    0.25                    0.00
# 2_7lYF6P2cYKnSiPhhVyPQ                    0.20                    0.25
# 3gL18eXylqutlzqb6TmB0w                    0.00                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                    0.20                    0.00
#
# business_id             xM8dVGLkYaL94EuAIkjMEA  y3IVqEFHmrkgVKj2x1Ci4w  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                     0.0
# 3gL18eXylqutlzqb6TmB0w                     0.0                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                     0.0
#
# business_id             yyGzYDh0Qa2o8vUGMEjDRA  zBeUDwWx73QTZ34A1l0adQ
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                    0.00
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                    0.25
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                    0.20
# 3gL18eXylqutlzqb6TmB0w                     0.0                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                    0.20
#
# [5 rows x 36 columns]

# %%
def predict_ratings(similarity, utility, to_predict):
    """Predicts the predicted rating for the input test data.
    
    Arguments:
    similarity -- a dataFrame that describes the similarity between items
    utility    -- a dataFrame that contains a rating for each user (columns) and each movie (rows). 
                  If a user did not rate an item the value np.nan is assumed. 
    to_predict -- A dataFrame containing at least the columns movieId and userId for which to do the predictions
    """
    # copy input (don't overwrite)
    ratings_test_c = to_predict.copy()
    # apply prediction to each row
    ratings_test_c['predicted rating'] = to_predict.apply(lambda row: predict_ids(similarity, utility, row['business_id'], row['categories']), axis=1)
    return ratings_test_c


def predict_ids(similarity, utility, userId, itemId):
    # select right series from matrices and compute
    if userId in utility.columns and itemId in similarity.index:
        return predict_vectors(utility.loc[:,userId], similarity[itemId])
    return 0

def predict_vectors(user_ratings, similarities):
    relevant_ratings = user_ratings.dropna()
    similarities_s = similarities[relevant_ratings.index]
    similarities_s = similarities_s[similarities_s > 0.0]
    relevant_ratings = relevant_ratings[similarities_s.index]
    norm = similarities_s.sum()
    if(norm == 0):
        return 0
    return np.dot(relevant_ratings, similarities_s)/norm

# %%
prediction = predict_ratings(cat, cat, cat[['user_id', 'business_id', 'categories']])
display(prediction)
# Out:
#                     user_id             business_id  \
# 0    hXydWH25S92HjI5hmWRSyA  dJ0R-XT78LUQeNHQkD-G9g
# 206  g08bkzhvjsST-0g2TfEg7Q  N92Pbr2ygKDLkjmr-4BAPw
# 220  wFFLWorAWh3hpxVLQP8YWw  N92Pbr2ygKDLkjmr-4BAPw
# 219  sy_uis3d_sgIGodPZktQcQ  N92Pbr2ygKDLkjmr-4BAPw
# 216  QNecf-DovpR9IVq1z1YJbw  N92Pbr2ygKDLkjmr-4BAPw
# ..                      ...                     ...
# 172  gB8hGkSEUT5n6VPGHXYjbA  pcbVl6ZHDOJHsnetY0rJEQ
# 89   NOR93THAvtPUrJlzP9a3pA  ftx72aqADrNYmOlMytdtCg
# 243  1gJw6DxTrf0Zmp9gDgYlrQ  LHd0Y_0tIWWPvRqDb2b74Q
# 168  Uz51g_KgDx7nHyHD2OXZLA  EZ9zSk4ld27LwgfANoF4VA
# 188  VENurDsqZxxtSxlQBN5i0w  N92Pbr2ygKDLkjmr-4BAPw
#
#                           categories  predicted rating
# 0    Food, Ice Cream & Frozen Yogurt                 0
# 206                              NaN                 0
# 220                              NaN                 0
# 219                              NaN                 0
# 216                              NaN                 0
# ..                               ...               ...
# 172                              NaN                 0
# 89                               NaN                 0
# 243                              NaN                 0
# 168                              NaN                 0
# 188                              NaN                 0
#
# [379 rows x 4 columns]

# %% [markdown]
# <H2>Evaluation
# DIT MOET NOG AANGEPAST ZODAT HET PAST BIJ ITEM BASED ALGORITME</H2>

# %%
treshold_used = 4

def get_confusion(prediction, treshold):
    re = recommended(prediction, treshold)
    hi = hidden(prediction, treshold)
    us = used(prediction, treshold_used)
    un = unused(prediction, treshold_used)
    
    return confusion(re, hi, us, un)

def recommended(predictions, treshold):
    predictions = predictions[predictions["predicted rating"] >= treshold]
    return predictions

def hidden(predictions, treshold):
    predictions = predictions[predictions["predicted rating"] < treshold]
    return predictions

def used(predictions, treshold):
    predictions = predictions[predictions["stars"] >= treshold]
    return predictions
    
def unused(predictions, treshold):
    predictions = predictions[predictions["stars"] < treshold]
    return predictions

def confusion(recommended, hidden, used, unused):
    true_positive = len(recommended.index.intersection(used.index))
    false_positive = len(recommended.index.intersection(unused.index))
    true_negative = len(hidden.index.intersection(unused.index))
    false_negative = len(hidden.index.intersection(used.index))
    
    solution = pd.DataFrame([[true_positive, false_positive], [false_negative, true_negative]], columns=['used', 'unused'],
                         index=['recommended', 'hidden'])
    return solution
    
def precision(confusion_matrix):
    true_positives = confusion_matrix["used"]["recommended"]
    recommended = confusion_matrix["used"]["recommended"] + confusion_matrix["unused"]["recommended"]
    return true_positives/recommended

def recall(confusion_matrix):
    true_positives = confusion_matrix["used"]["recommended"]
    used_items = confusion_matrix["used"]["recommended"] + confusion_matrix["used"]["hidden"]
    return true_positives/used_items

# %%
tresholds = [2.5, 3.0, 3.5, 4.0, 4.5]

def plot_precision_recall(prediction, tresholds):
    recalls = []
    precisons = []
    for treshold in tresholds:
        confusion = get_confusion(prediction, treshold)
        precisons.append(precision(confusion))
        recalls.append(recall(confusion))
    
    plt.plot(recalls, precisons)
    for r, p, t in zip(recalls, precisons, tresholds):
        plt.text(r, p, t)
        


plt.xlabel('recall')
plt.ylabel('precision')        

plot_precision_recall(predicted_item_based_cosine, tresholds)        
plot_precision_recall(predicted_item_based_euclidean, tresholds)
plot_precision_recall(predicted_item_based_I, tresholds) 
plot_precision_recall(predicted_item_based_II, tresholds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-df4973ec1f1b> in <module>
#      18 plt.ylabel('precision')
#      19
# ---> 20 plot_precision_recall(predicted_item_based_cosine, tresholds)
#      21 plot_precision_recall(predicted_item_based_euclidean, tresholds)
#      22 plot_precision_recall(predicted_item_based_I, tresholds)
#
# NameError: name 'predicted_item_based_cosine' is not defined
