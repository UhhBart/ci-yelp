# %% [markdown]
# **LETSGOOOOOOOOO**

# %% [markdown]
# TEST TEST TEST TEST hugo test

# %% [markdown]
# TEST2 TEST2 TEST 2 hugo test 2

# %%
from pandas import Series, Timestamp
import pandas as pd
from pandas import DataFrame
import numpy as np
import simplejson as json

# %%
def load_jsons(data_path, file):
    """ helper function to load '.json' files (they're not proper jsons) """
    file_path = data_path + file
    with open(file_path) as jsons:
        lines = [json.loads(json_line) for json_line in jsons]
    return pd.DataFrame(lines)

# %%
# Load data for town called Ambridge
data_path = './data/ambridge/'

# Seperate the files 
review_file = 'review.json'
business_file = 'business.json'
user_file = 'user.json'
tip_file = 'tip.json'
checkin_file = 'checkin.json'

reviews = load_jsons(data_path, review_file)
businesses = load_jsons(data_path, business_file)
users = load_jsons(data_path, user_file)
tips = load_jsons(data_path, tip_file)
checkins = load_jsons(data_path, checkin_file)

display(businesses)
# Out:
#                business_id                                    name  \
# 0   dJ0R-XT78LUQeNHQkD-G9g                       Ice Cream Therapy
# 1   3gL18eXylqutlzqb6TmB0w                     Action Tire Company
# 2   Q_0eGl-aElqHKukHvmLdwA                      Nelia's Smokehouse
# 3   Eu_zPTrNVAXkpdSxf7CJ2w                        K & N Restaurant
# 4   Yjf0i2J9q52dYIT8UVGT3g                  Heritage Floral Shoppe
# 5   y3IVqEFHmrkgVKj2x1Ci4w                    Off the Hook Exotics
# 6   729grSa1Wsn-hfv7D5uOxg                             Pizza House
# 7   rdHO0LkiNe6s3716hPuQXQ                        Firehouse Lounge
# 8   iJhb_2JL1uIbIRYUl41uVg               Pucktastic Auto Detailing
# 9   NHhzHVKVizOvA61AyN-dSw                 Ambridge Wholesale Tire
# 10  ftx72aqADrNYmOlMytdtCg                        Maid On The Spot
# 11  RdEb3U0CDIXElVJe3w5n6g                         Stangl's Bakery
# 12  7xRbOtZUuw7DxOWrHeaanw            Annie Lee's Southern Kitchen
# 13  2_7lYF6P2cYKnSiPhhVyPQ                               Orbit Inn
# 14  EZ9zSk4ld27LwgfANoF4VA                     Ambridge Do It Best
# 15  0EyRe-VkW8gYxxZ7NCQXeQ                         Fox's Pizza Den
# 16  4mpSNvmyG89Uqy2ahP4JMQ                      Tex-Mix Restaurant
# 17  tTDxa8OzmxUkpVifQ-cEWw                                Ni's Wok
# 18  pcbVl6ZHDOJHsnetY0rJEQ  Stonebridge Farm Landscaping & Nursery
# 19  N92Pbr2ygKDLkjmr-4BAPw                     Bridgetown Taphouse
# 20  gOu6hTevtDeTBNMOjo6fsw                            Vape With It
# 21  zBeUDwWx73QTZ34A1l0adQ                           Vocelli Pizza
# 22  EOmRHPvzR88a5R2j2uD0cQ                               Caffe 501
# 23  TsusMt8MhyWaQOVL-MLnjA            Mikush Home Appliance Center
# 24  LHd0Y_0tIWWPvRqDb2b74Q                            Fred's Divot
# 25  lawYwEXAE-Sq2nf6co7aBg                            Hark's Place
# 26  yyGzYDh0Qa2o8vUGMEjDRA                      Rivertown Antiques
# 27  KQrgpqBmIsBbdAn6CnfgCA                    Tick Tock Bar & Cafe
# 28  c_3u2TfMWtt8OlRFYtVo_Q                 Tom's Old Country Store
# 29  t_EiW3FlMnFTHyoeVU79xg                 Rook's East Side Saloon
# 30  -InU2nAbC9AuS-Um2Cowgw                        Maple Restaurant
# 31  KLptkOv3OiNSTU4unZv9Sg                  Little Athens Catering
# 32  GI1WxFbY9tJ9-ChRrwnrzg                      The Stuffed Pepper
# 33  muFJIZKZwbAfy_pEFKF_pw                        Frank's Pizzeria
# 34  XJfvPt-8f-6d5Foaz_HYLQ                        Breakfast Shoppe
# 35  xM8dVGLkYaL94EuAIkjMEA                     Old Economy Village
#
#                 address      city state postal_code   latitude  longitude  \
# 0       400 Merchant St  Ambridge    PA       15003  40.584100 -80.225135
# 1          304 Duss Ave  Ambridge    PA       15003  40.582380 -80.223875
# 2          603 Duss Ave  Ambridge    PA       15003  40.587939 -80.224885
# 3       755 Merchant St  Ambridge    PA       15003  40.588606 -80.229103
# 4       663 Merchant St  Ambridge    PA       15003  40.587650 -80.228493
# 5       598 Merchant St  Ambridge    PA       15003  40.586533 -80.226988
# 6      1007 Merchant St  Ambridge    PA       15003  40.592077 -80.230377
# 7      1301 Merchant St  Ambridge    PA       15003  40.595781 -80.230735
# 8           207 12th St  Ambridge    PA       15003  40.594775 -80.231370
# 9      1006 Merchant St  Ambridge    PA       15003  40.591926 -80.229877
# 10     1521 Merchant St  Ambridge    PA       15003  40.598194 -80.230785
# 11      572 Merchant St  Ambridge    PA       15003  40.586411 -80.226881
# 12        1601 Duss Ave  Ambridge    PA       15003  40.599245 -80.226472
# 13     1327 Merchant St  Ambridge    PA       15003  40.596327 -80.230855
# 14  500 Ohio River Blvd  Ambridge    PA       15003  40.584188 -80.228628
# 15     1204 Merchant St  Ambridge    PA       15003  40.594851 -80.230291
# 16         603 Duss Ave  Ambridge    PA       15003  40.587920 -80.224920
# 17      703 Merchant St  Ambridge    PA       15003  40.588011 -80.228581
# 18        2 Merriman Rd  Ambridge    PA       15003  40.592976 -80.200609
# 19      939 Merchant St  Ambridge    PA       15003  40.591308 -80.230225
# 20      916 Merchant St  Ambridge    PA       15003  40.590541 -80.229986
# 21      447 Merchant St  Ambridge    PA       15003  40.584533 -80.226168
# 22     501 Glenwood Ave  Ambridge    PA       15003  40.585843 -80.224834
# 23      811 Merchant St  Ambridge    PA       15003  40.589394 -80.229583
# 24      816 Merchant St  Ambridge    PA       15003  40.589563 -80.229250
# 25         70 Beaver St  Ambridge    PA       15003  40.579862 -80.220941
# 26     1307 Merchant St  Ambridge    PA       15003  40.596105 -80.230955
# 27     1101 Merchant St  Ambridge    PA       15003  40.593082 -80.230846
# 28      511 Merchant St  Ambridge    PA       15003  40.585307 -80.226756
# 29           282 4th St  Ambridge    PA       15003  40.583216 -80.225616
# 30    463 Maplewood Ave  Ambridge    PA       15003  40.584463 -80.227219
# 31      499 Merchant St  Ambridge    PA       15003  40.585017 -80.226311
# 32        1601 Duss Ave  Ambridge    PA       15003  40.599344 -80.226543
# 33         618 Duss Ave  Ambridge    PA       15003  40.588256 -80.224529
# 34        1507 Duss Ave  Ambridge    PA       15003  40.598306 -80.226424
# 35     270 Sixteenth St  Ambridge    PA       15003  40.592745 -80.232176
#
#     stars  review_count  is_open  \
# 0     3.5             3        1
# 1     5.0             4        1
# 2     4.0            18        0
# 3     4.5            14        1
# 4     4.5             4        1
# 5     4.0             5        1
# 6     4.5            32        1
# 7     4.0             5        1
# 8     5.0             3        1
# 9     4.5             3        1
# 10    4.5             8        1
# 11    4.0             5        1
# 12    4.5             6        1
# 13    3.0             4        1
# 14    3.5             5        1
# 15    4.5             7        1
# 16    3.5             9        1
# 17    3.0             4        1
# 18    3.0             4        1
# 19    4.5            68        1
# 20    3.5             3        1
# 21    2.0             3        1
# 22    4.5             9        1
# 23    3.5             3        1
# 24    2.5             3        1
# 25    4.0             6        1
# 26    4.0             5        1
# 27    3.5            10        1
# 28    5.0             3        1
# 29    3.0             8        0
# 30    4.0            48        1
# 31    4.5            11        1
# 32    4.5             4        0
# 33    4.5            28        1
# 34    4.5             4        1
# 35    5.0             6        1
#
#                                            attributes  \
# 0                                                None
# 1              {'BusinessAcceptsCreditCards': 'True'}
# 2   {'Alcohol': 'u'none'', 'OutdoorSeating': 'Fals...
# 3   {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 4   {'BusinessParking': '{'garage': False, 'street...
# 5                                                None
# 6   {'RestaurantsReservations': 'False', 'Restaura...
# 7   {'HappyHour': 'True', 'GoodForDancing': 'False...
# 8              {'BusinessAcceptsCreditCards': 'True'}
# 9              {'BusinessAcceptsCreditCards': 'True'}
# 10  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 11  {'RestaurantsPriceRange2': '1', 'RestaurantsDe...
# 12  {'DogsAllowed': 'False', 'RestaurantsTableServ...
# 13  {'GoodForMeal': '{'dessert': False, 'latenight...
# 14  {'BusinessParking': '{'garage': False, 'street...
# 15                                               None
# 16  {'RestaurantsTableService': 'True', 'BusinessP...
# 17                                               None
# 18  {'BikeParking': 'False', 'BusinessParking': '{...
# 19  {'OutdoorSeating': 'False', 'Smoking': 'u'no''...
# 20                                               None
# 21                                               None
# 22  {'RestaurantsDelivery': 'False', 'RestaurantsP...
# 23  {'RestaurantsPriceRange2': '2', 'BusinessParki...
# 24  {'BusinessParking': '{'garage': False, 'street...
# 25  {'HasTV': 'True', 'RestaurantsReservations': '...
# 26  {'ByAppointmentOnly': 'True', 'RestaurantsPric...
# 27  {'DogsAllowed': 'False', 'WheelchairAccessible...
# 28  {'ByAppointmentOnly': 'False', 'BusinessParkin...
# 29  {'GoodForKids': 'True', 'RestaurantsPriceRange...
# 30  {'BusinessParking': '{'garage': False, 'street...
# 31  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 32  {'RestaurantsTakeOut': 'True', 'Ambience': '{'...
# 33  {'RestaurantsPriceRange2': '1', 'RestaurantsAt...
# 34  {'RestaurantsAttire': ''casual'', 'Ambience': ...
# 35                            {'GoodForKids': 'True'}
#
#                                            categories  \
# 0                     Food, Ice Cream & Frozen Yogurt
# 1   Auto Repair, Smog Check Stations, Tires, Autom...
# 2   Filipino, Food, Restaurants, Barbeque, Smokehouse
# 3   Breakfast & Brunch, Restaurants, American (Tra...
# 4                 Florists, Flowers & Gifts, Shopping
# 5                                    Pets, Pet Stores
# 6                                  Restaurants, Pizza
# 7               Lounges, Nightlife, Restaurants, Bars
# 8                Car Wash, Automotive, Auto Detailing
# 9   Auto Repair, Automotive, Tires, Auto Parts & S...
# 10  Home Services, Professional Services, Local Se...
# 11  Bakeries, Food, Restaurants, Desserts, Farmers...
# 12                    Southern, Barbeque, Restaurants
# 13  American (Traditional), Restaurants, Nightlife...
# 14  Home Decor, Shopping, Hardware Stores, Home & ...
# 15                     Sandwiches, Pizza, Restaurants
# 16               Mexican, Restaurants, Tex-Mex, Tacos
# 17                               Chinese, Restaurants
# 18     Shopping, Nurseries & Gardening, Home & Garden
# 19  American (Traditional), Music Venues, Nightlif...
# 20                               Shopping, Vape Shops
# 21                                 Pizza, Restaurants
# 22                       Bakeries, Coffee & Tea, Food
# 23  Local Services, Appliances, Home & Garden, App...
# 24            Dive Bars, Sports Bars, Bars, Nightlife
# 25                       Bars, Sports Bars, Nightlife
# 26                                 Antiques, Shopping
# 27  Restaurants, Delis, Bars, Nightlife, Sports Ba...
# 28                                 Antiques, Shopping
# 29  Restaurants, Pubs, Nightlife, American (New), ...
# 30     Restaurants, Sandwiches, Salad, American (New)
# 31  Caterers, Greek, Restaurants, Event Planning &...
# 32                               Italian, Restaurants
# 33                                 Pizza, Restaurants
# 34  Restaurants, Food, Sandwiches, Breakfast & Bru...
# 35                      Museums, Arts & Entertainment
#
#                                                 hours
# 0   {'Monday': '15:0-22:0', 'Tuesday': '15:0-22:0'...
# 1   {'Monday': '6:30-16:0', 'Tuesday': '6:30-16:0'...
# 2   {'Monday': '11:0-19:0', 'Tuesday': '11:0-19:0'...
# 3   {'Monday': '6:0-19:0', 'Tuesday': '6:0-19:0', ...
# 4   {'Monday': '9:0-16:0', 'Tuesday': '9:0-16:0', ...
# 5                                                None
# 6   {'Monday': '17:0-23:0', 'Tuesday': '17:0-23:0'...
# 7   {'Monday': '9:0-2:0', 'Tuesday': '9:0-2:0', 'W...
# 8   {'Monday': '0:0-0:0', 'Saturday': '8:0-20:0', ...
# 9   {'Monday': '0:0-0:0', 'Tuesday': '8:30-18:30',...
# 10  {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...
# 11  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 12  {'Monday': '0:0-0:0', 'Tuesday': '11:0-19:0', ...
# 13                                               None
# 14  {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...
# 15                                               None
# 16  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 17                                               None
# 18                                               None
# 19  {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...
# 20  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 21  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 22  {'Monday': '6:0-14:0', 'Tuesday': '6:0-14:0', ...
# 23  {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# 24                                               None
# 25  {'Monday': '10:0-2:0', 'Tuesday': '10:0-2:0', ...
# 26  {'Monday': '12:0-16:0', 'Tuesday': '10:30-17:0...
# 27  {'Monday': '7:0-2:0', 'Tuesday': '7:0-2:0', 'W...
# 28                                               None
# 29                                               None
# 30  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 31  {'Monday': '11:0-19:0', 'Tuesday': '11:0-19:0'...
# 32  {'Tuesday': '10:30-20:30', 'Wednesday': '10:30...
# 33  {'Tuesday': '18:0-22:0', 'Wednesday': '18:0-22...
# 34  {'Monday': '7:0-14:0', 'Tuesday': '7:0-14:0', ...
# 35  {'Wednesday': '10:0-17:0', 'Thursday': '10:0-1...

# %% [markdown]
# # CONTENT BASED FILTERING STARTS HERE LETS FUCKING GOOOOOO

# %%
"""
All these functions were taken and modified from module 3
"""

def extract_categories(businesses):
    categories = businesses.apply(lambda row: pd.Series([row['business_id']] + row['categories'].lower().split(",")), axis=1)
    stack_categories = categories.set_index(0).stack()
    df_stack_categories = stack_categories.to_frame()
    df_stack_categories['business_id'] = stack_categories.index.droplevel(1)
    df_stack_categories.columns = ['category', 'business_id']
    return df_stack_categories.reset_index()[['business_id', 'category']]

def pivot_categories(df):
    """Create a one-hot encoded matrix for categories.
    
    Arguments:
    df -- a dataFrame containing at least the columns 'businessId' and 'category'
    
    Output:
    a matrix containing '0' or '1' in each cell.
    1: the business has the category
    0: the business does not have the category
    """
    return df.pivot_table(index = 'business_id', columns = 'category', aggfunc = 'size', fill_value=0)

def create_similarity_matrix_jaccard(matrix):
    m11 = matrix @ matrix.T
    m10 = pd.DataFrame(matrix.sum(axis = 1).values + np.zeros(m11.shape), index = m11.index, columns = m11.index)
    m01 = m10.T
    return m11/(m01 + m10 - m11)

categories = extract_categories(businesses)
df_utility_categories = pivot_categories(categories)
similarity_matrix_categories = create_similarity_matrix_jaccard(df_utility_categories)

# %%
display(similarity_matrix_categories.head())
# Out:
# business_id             -InU2nAbC9AuS-Um2Cowgw  0EyRe-VkW8gYxxZ7NCQXeQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     1.0                0.000000
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                1.000000
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                0.166667
# 3gL18eXylqutlzqb6TmB0w                     0.0                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                0.166667
#
# business_id             2_7lYF6P2cYKnSiPhhVyPQ  3gL18eXylqutlzqb6TmB0w  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.166667                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                1.000000                     0.0
# 3gL18eXylqutlzqb6TmB0w                0.000000                     1.0
# 4mpSNvmyG89Uqy2ahP4JMQ                0.142857                     0.0
#
# business_id             4mpSNvmyG89Uqy2ahP4JMQ  729grSa1Wsn-hfv7D5uOxg  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                    0.20
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.166667                    0.25
# 2_7lYF6P2cYKnSiPhhVyPQ                0.142857                    0.00
# 3gL18eXylqutlzqb6TmB0w                0.000000                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                1.000000                    0.00
#
# business_id             7xRbOtZUuw7DxOWrHeaanw  EOmRHPvzR88a5R2j2uD0cQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.200000                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                0.166667                     0.0
# 3gL18eXylqutlzqb6TmB0w                0.000000                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                0.166667                     0.0
#
# business_id             EZ9zSk4ld27LwgfANoF4VA  Eu_zPTrNVAXkpdSxf7CJ2w  ...  \
# business_id                                                             ...
# -InU2nAbC9AuS-Um2Cowgw                     0.0                0.000000  ...
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                0.200000  ...
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                0.166667  ...
# 3gL18eXylqutlzqb6TmB0w                     0.0                0.000000  ...
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                0.166667  ...
#
# business_id             lawYwEXAE-Sq2nf6co7aBg  muFJIZKZwbAfy_pEFKF_pw  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                0.000000                    0.00
# 0EyRe-VkW8gYxxZ7NCQXeQ                0.000000                    0.25
# 2_7lYF6P2cYKnSiPhhVyPQ                0.166667                    0.20
# 3gL18eXylqutlzqb6TmB0w                0.000000                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                0.000000                    0.20
#
# business_id             pcbVl6ZHDOJHsnetY0rJEQ  rdHO0LkiNe6s3716hPuQXQ  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                0.000000
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                0.166667
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                0.600000
# 3gL18eXylqutlzqb6TmB0w                     0.0                0.000000
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                0.142857
#
# business_id             tTDxa8OzmxUkpVifQ-cEWw  t_EiW3FlMnFTHyoeVU79xg  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                    0.00                    0.25
# 0EyRe-VkW8gYxxZ7NCQXeQ                    0.25                    0.00
# 2_7lYF6P2cYKnSiPhhVyPQ                    0.20                    0.25
# 3gL18eXylqutlzqb6TmB0w                    0.00                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                    0.20                    0.00
#
# business_id             xM8dVGLkYaL94EuAIkjMEA  y3IVqEFHmrkgVKj2x1Ci4w  \
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                     0.0
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                     0.0
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                     0.0
# 3gL18eXylqutlzqb6TmB0w                     0.0                     0.0
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                     0.0
#
# business_id             yyGzYDh0Qa2o8vUGMEjDRA  zBeUDwWx73QTZ34A1l0adQ
# business_id
# -InU2nAbC9AuS-Um2Cowgw                     0.0                    0.00
# 0EyRe-VkW8gYxxZ7NCQXeQ                     0.0                    0.25
# 2_7lYF6P2cYKnSiPhhVyPQ                     0.0                    0.20
# 3gL18eXylqutlzqb6TmB0w                     0.0                    0.00
# 4mpSNvmyG89Uqy2ahP4JMQ                     0.0                    0.20
#
# [5 rows x 36 columns]

# %%
user_dataframe = pd.DataFrame(users)

display(user_dataframe)
# Out:
#                     user_id     name  review_count        yelping_since  \
# 0    3FjdHwnoz-vfw6hBBtckqg    Maria           445  2008-03-26 18:35:10
# 1    rCWrxuRC8_pfagpchtHp6A   Darren          1449  2009-02-06 06:45:55
# 2    9YIEYRTM1-esrPtfTVU4LA    David            29  2014-05-18 22:53:49
# 3    _pLmakEC1U8UPpxCUk2ZAg     Erin            12  2010-10-21 23:00:28
# 4    ZnIaEvJwrxlBUjimIpx2Qw      Kat           240  2010-08-12 04:40:22
# ..                      ...      ...           ...                  ...
# 276  lL9Sppyk-mzNGJ5Uloz5-g     Mark             4  2013-03-15 22:57:48
# 277  fM8rythOmJGL-IRsiYdZqg   Alfred             5  2017-03-09 18:05:53
# 278  IjiXC9ekXkP1I9kdLWogEw     Jeff             2  2015-09-19 23:49:11
# 279  01vXmAJKQ41PVi2wgYDiPA       Ca             5  2016-02-19 19:06:56
# 280  391zaCfgqkE_4WM3Up-z9Q  Colleen             9  2012-03-23 03:06:38
#
#      useful  funny   cool                               elite  \
# 0       718    193    377  2008,2009,2014,2015,2016,2017,2018
# 1     17459  13033  14714
# 2        63     14     14                           2016,2017
# 3         8      2      2
# 4       220     67     97                      2016,2017,2018
# ..      ...    ...    ...                                 ...
# 276       4      0      0
# 277       0      0      1
# 278       0      0      0
# 279       5      1      0
# 280       2      0      1
#
#                                                friends  fans  ...  \
# 0    lgKMgS9KCIo5olvvM5gClw, y6og6ueUObeQNYkzgNjZDg...    31  ...
# 1    GvqIvPeMkchQ8jYhPY7lXg, 8ugd_yB1RecZMCWfSsr3GQ...   250  ...
# 2    C4fKnSeNkD904ZeQLr5xVw, rVAiIWafD-4UuLLnjLzUMA...     4  ...
# 3    wDF8cwQOjn87BjjPDr6vTw, uB4NDnKvS-O07cQ5pq_eCA...     0  ...
# 4    aPEj8geDZjVNT53wvsWEUQ, getX31OKf2IZ5QvpruTNtQ...     4  ...
# ..                                                 ...   ...  ...
# 276  XBMFEOxsul_HALa34wEY8w, H0QzvFRXIIpTxj6nWCH_GQ...     0  ...
# 277  boXAA22H2Z56XMRGf-fj7g, WlDARpCLkOBGqa20X8b3hA...     2  ...
# 278                                               None     0  ...
# 279                                               None     0  ...
# 280                                               None     0  ...
#
#      compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0                  6                   0                1                1
# 1                115                 120               37               37
# 2                  0                   0                0                0
# 3                  0                   0                0                0
# 4                  0                   0                0                0
# ..               ...                 ...              ...              ...
# 276                0                   0                0                0
# 277                0                   0                0                0
# 278                0                   0                0                0
# 279                0                   0                0                0
# 280                0                   0                0                0
#
#      compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0                 15                15               34                34
# 1                758              2123             1408              1408
# 2                  1                 2                1                 1
# 3                  0                 0                1                 1
# 4                  2                 1                1                 1
# ..               ...               ...              ...               ...
# 276                0                 0                0                 0
# 277                0                 0                0                 0
# 278                0                 0                0                 0
# 279                0                 0                0                 0
# 280                0                 0                0                 0
#
#      compliment_writer  compliment_photos
# 0                   27                  3
# 1                 1151                403
# 2                    1                  0
# 3                    0                  0
# 4                    3                  1
# ..                 ...                ...
# 276                  0                  0
# 277                  0                  0
# 278                  0                  0
# 279                  0                  0
# 280                  0                  0
#
# [281 rows x 22 columns]

# %%
def predict_ratings(similarity, utility, to_predict):
    """Predicts the predicted rating for the input test data.
    
    Arguments:
    similarity -- a dataFrame that describes the similarity between items
    utility    -- a dataFrame that contains a rating for each user (columns) and each movie (rows). 
                  If a user did not rate an item the value np.nan is assumed. 
    to_predict -- A dataFrame containing at least the columns movieId and userId for which to do the predictions
    """
    # copy input (don't overwrite)
    ratings_test_c = to_predict.copy()
    # apply prediction to each row
    ratings_test_c['predicted category'] = to_predict.apply(lambda row: predict_ids(similarity, utility, row['categories'], row['business_id']), axis=1)
    return ratings_test_c


def predict_ids(similarity, utility, userId, itemId):
    # select right series from matrices and compute
    if userId in utility.columns and itemId in similarity.index:
        return predict_vectors(utility.loc[:,userId], similarity[itemId])
    return 0

# %%
prediction = predict_ratings(similarity_matrix_categories, businesses, businesses[['name', 'business_id', 'categories']])
display(prediction)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-5edeb666fbf6> in <module>
# ----> 1 prediction = predict_ratings(similarity_matrix_categories, businesses, user_dataframe[['name', 'business_id', 'categories']])
#       2 display(prediction)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1643             if not (self.name == "loc" and not raise_missing):
#    1644                 not_found = list(set(key) - set(ax))
# -> 1645                 raise KeyError(f"{not_found} not in index")
#    1646
#    1647             # we skip the warning on Categorical/Interval
#
# KeyError: "['categories', 'business_id'] not in index"
