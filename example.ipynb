# %%
import pandas as pd
import json

def load_jsons(data_path, file):
    """ helper function to load '.json' files (they're not proper jsons) """
    file_path = data_path + file
    with open(file_path) as jsons:
        lines = [json.loads(json_line) for json_line in jsons]
    return pd.DataFrame(lines)

# %%
# Load data for town called Ambridge
data_path = '../data/brossard/'
review_file = 'review.json'
business_file = 'business.json'
user_file = 'user.json'
tip_file = 'tip.json'
checkin_file = 'checkin.json'

reviews = load_jsons(data_path, review_file)
businesses = load_jsons(data_path, business_file)
users = load_jsons(data_path, user_file)
tips = load_jsons(data_path, tip_file)
checkins = load_jsons(data_path, checkin_file)

# %%
display(reviews.head())
display(businesses.head())
display(users.head())
display(tips.head())
display(checkins.head())
# Out:
#                 review_id                 user_id             business_id  \
# 0  Ccc3ZAXEw69lGZg5oAZKHw  YZ7S0_eemKwWR5tHkaMUqw  JD55YRLwptXJVkMRekbzNg
# 1  aZOOTcXB28ftRZJnQDMjjA  UiU_yqwSQwTZdw3vxD_Aag  JD55YRLwptXJVkMRekbzNg
# 2  9qRSlEj4Rcd3NXektgI1hA  vu9dmqZiZSm3ijUP-7HmKA  VvZnozdEpjw0e7Dg-kKIxg
# 3  KTcqaTj8sHT0zJ0V-p1Kjg  S-t12afI5gGgVWZTV3iQNQ  n2dhdtnOzqeAKSn6s3nQSw
# 4  22vF44g9TIDsQOpmvVVg6A  _FKhZ0r6uTBNHA_ALWyGqg  KE7cmEKW8IwMFAdmzP72rQ
#
#    stars  useful  funny  cool  \
# 0    2.0       0      0     0
# 1    4.0       0      0     0
# 2    4.0       0      0     0
# 3    2.0       0      0     0
# 4    1.0       1      0     0
#
#                                                 text                 date
# 0  Average food and service. Kind of dirty and so...  2017-08-16 04:35:11
# 1  Probably one of the best Vietnamese restaurant...  2017-12-02 20:13:24
# 2  Petit restaurant, déco un peu vieillote, mais ...  2014-10-27 03:10:16
# 3  We went there on a friday night, the whole pla...  2017-01-14 21:20:25
# 4  Pour un restaurant Italien qui pense que Sauce...  2015-06-08 19:09:25
#               business_id                       name  \
# 0  ijf9tBHePS0hpZ9GdZwz8g              Crux Comptoir
# 1  KQOnL835AZEL9k881euCPQ                Le Magnolia
# 2  J9j4TAdPOwwUDhFTCiZOVA            Quartier Dix-30
# 3  qxdZWoRVwf4lpI_gjAN2gA  Le Bol d'or / Golden Bowl
# 4  6qa_KEqzJ9rqm70qqRly0w         Mon Ami - Brossard
#
#                            address      city state postal_code   latitude  \
# 0  9180 Boulevard Leduc, Suite 115  Brossard    QC     J4Y 0L1  45.446590
# 1        7350 Blvd Taschereau, 44D  Brossard    QC       J4W 1  45.459506
# 2              6000 Boulevard Rome  Brossard    QC     J4Y 0B6  45.441072
# 3              1200 Boulevard Rome  Brossard    QC     J4W 3H3  45.457785
# 4      5455 Boulevard Grande-Allée  Brossard    QC     J4Z 3H1  45.477253
#
#    longitude  stars  review_count  is_open  \
# 0 -73.437164    5.0             5        1
# 1 -73.467366    2.0             4        1
# 2 -73.440259    3.5            23        1
# 3 -73.490531    2.5            15        1
# 4 -73.447508    4.0             8        1
#
#                                           attributes  \
# 0  {'Ambience': 'None', 'RestaurantsReservations'...
# 1                    {'RestaurantsPriceRange2': '1'}
# 2  {'BikeParking': 'True', 'DogsAllowed': 'True',...
# 3  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 4  {'HasTV': 'True', 'RestaurantsPriceRange2': '2...
#
#                                           categories  \
# 0  Juice Bars & Smoothies, Restaurants, Organic S...
# 1                Shopping, Flowers & Gifts, Florists
# 2                         Shopping Centers, Shopping
# 3                               Chinese, Restaurants
# 4             Buffets, Barbeque, Korean, Restaurants
#
#                                                hours
# 0  {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...
# 1                                               None
# 2  {'Monday': '10:0-18:0', 'Tuesday': '10:0-18:0'...
# 3                                               None
# 4  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...
#                   user_id     name  review_count        yelping_since  useful  \
# 0  KYuOv0JCfJWZMoT0zVK3SQ  William           121  2011-02-06 22:22:38     185
# 1  WCHArapR0ZhduJElR9axjA    Farin           145  2011-01-23 18:35:12     260
# 2  ebJwvy8BJJXB0IPWgt_p5Q     Jaki             1  2016-04-05 22:45:00       0
# 3  HW-QgyCq4DzUQCFRaYn6Fg   Walter           588  2009-03-05 16:03:31    1237
# 4  yRgJ0HkDOkA0UeE09CiXAw        D            60  2014-08-19 19:44:26      55
#
#    funny  cool                                         elite  \
# 0     70    76                                2012,2013,2014
# 1     61   146                                2012,2013,2014
# 2      0     0
# 3    318   551  2009,2010,2011,2012,2013,2014,2015,2016,2017
# 4     36    18
#
#                                              friends  fans  ...  \
# 0  GOfgKv_Gh5LEKVfK5xjcfA, C9NqbS13gbCswi2RS6SsSg...     5  ...
# 1  FuW1EwnbQoHyDMeOGrljsg, HuBgs7uHyUz7DzcaScZqjg...     7  ...
# 2  o625Oua6du8sO4sUFV5u-Q, fKKUZeIKLYiCHVShCDP_lA...     0  ...
# 3  j9ASEWvf-5vKwVxOCkjOwQ, 1JfHD63MIZbOjrYQ74vzvQ...    38  ...
# 4  yudgVIfAQzuP1tcaetfvlA, 9R2jFe5EgRHQ6NvoHSkVEQ...     4  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0                6                   0                0                0
# 1                1                   0                1                0
# 2                0                   0                0                0
# 3                1                   5                1                1
# 4                2                   0                0                0
#
#    compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0               32                15               17                17
# 1               11                20               34                34
# 2                0                 0                0                 0
# 3               26                44               54                54
# 4                0                 1                1                 1
#
#    compliment_writer  compliment_photos
# 0                 10                  0
# 1                 13                  1
# 2                  0                  0
# 3                 24                  3
# 4                  0                  0
#
# [5 rows x 22 columns]
#                   user_id             business_id  \
# 0  H6nyclAwhqJRyHvdso7qcw  H-uxYrrWdsw2plr14zkEQA
# 1  6yNwk5i7LtEmW3dULoaKog  qcY0PZc17ulyuaDfx0Kmyg
# 2  6yNwk5i7LtEmW3dULoaKog  Bgpo2QNx0NyrUnmDcWxenw
# 3  4nQ7MOkbc5u-DYUOgjiDsg  gd3Ba-Ukqlln7SjDXpcWKg
# 4  7Ri5xkuj6rMvD8F2zjWFow  -juOL0eJC6kvf5RLEjoPvA
#
#                                                 text                 date  \
# 0                        Double Caesars are awesome!  2014-09-01 02:50:05
# 1  Limited parking at store front; just park on t...  2016-01-19 17:57:23
# 2  This Allo Mon Coco location is ideally for loc...  2015-09-20 13:10:57
# 3  Make sure you check the prices once at the cas...  2017-03-12 15:52:28
# 4  Ask to be seated deeper inside if possible, so...  2013-12-21 17:03:16
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
#               business_id                                               date
# 0  -L9vtxgF0CZ25z-8HqHfDg           2017-11-03 17:58:28, 2018-08-04 15:33:47
# 1  -juOL0eJC6kvf5RLEjoPvA  2012-11-11 16:56:36, 2012-11-11 16:57:02, 2012...
# 2  -yEFjBrxf2r_BQzRnczzdw  2012-10-21 15:07:46, 2012-10-28 16:17:36, 2012...
# 3  1blpPH0_3jk2EnRz_Q_CuQ  2012-05-13 17:20:38, 2014-05-03 03:38:26, 2014...
# 4  1h3aXVtJLx2o4mArNuhf2w  2013-07-09 15:24:17, 2013-07-10 16:41:45, 2014...

# %%
# Pak enkel de ratings
ratings = reviews["stars"]

# Maak een figuur aan met daarin 1 
fig, (ax3) = plt.subplots(ncols=1)

ratings.hist(ax=ax3, color='Darkgreen')
ax3.grid(True)
ax3.set_xlabel("number of stars")
ax3.set_ylabel("occurances")
ax3.set_title("occurance of number of stars")
# Out:
# Text(0.5, 1.0, 'occurance of number of stars')

# %%
hello = pd.DataFrame({'stars':['1', '2', '3', '4'], 'val':[10, 30, 20, 40]})
display(hello)
# Out:
#   stars  val
# 0     1   10
# 1     2   30
# 2     3   20
# 3     4   40
