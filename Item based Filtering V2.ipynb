# %% [markdown]
# # item-based Sander en Hugo

# %%
import json
from pandas import Series, Timestamp
import pandas as pd
from pandas import DataFrame
from numpy import nan
from sklearn.metrics import median_absolute_error
import sklearn.metrics.pairwise as pw
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
def load_jsons(data_path, file):
    """ helper function to load '.json' files (they're not proper jsons) """
    file_path = data_path + file
    with open(file_path) as jsons:
        lines = [json.loads(json_line) for json_line in jsons]
    return pd.DataFrame(lines)

# %%
data_path = '../data/brossard/'
review_file = 'review.json'
reviews = load_jsons(data_path, review_file)

display(reviews.head())
# Out:
#                 review_id                 user_id             business_id  \
# 0  Ccc3ZAXEw69lGZg5oAZKHw  YZ7S0_eemKwWR5tHkaMUqw  JD55YRLwptXJVkMRekbzNg
# 1  aZOOTcXB28ftRZJnQDMjjA  UiU_yqwSQwTZdw3vxD_Aag  JD55YRLwptXJVkMRekbzNg
# 2  9qRSlEj4Rcd3NXektgI1hA  vu9dmqZiZSm3ijUP-7HmKA  VvZnozdEpjw0e7Dg-kKIxg
# 3  KTcqaTj8sHT0zJ0V-p1Kjg  S-t12afI5gGgVWZTV3iQNQ  n2dhdtnOzqeAKSn6s3nQSw
# 4  22vF44g9TIDsQOpmvVVg6A  _FKhZ0r6uTBNHA_ALWyGqg  KE7cmEKW8IwMFAdmzP72rQ
#
#    stars  useful  funny  cool  \
# 0    2.0       0      0     0
# 1    4.0       0      0     0
# 2    4.0       0      0     0
# 3    2.0       0      0     0
# 4    1.0       1      0     0
#
#                                                 text                 date
# 0  Average food and service. Kind of dirty and so...  2017-08-16 04:35:11
# 1  Probably one of the best Vietnamese restaurant...  2017-12-02 20:13:24
# 2  Petit restaurant, déco un peu vieillote, mais ...  2014-10-27 03:10:16
# 3  We went there on a friday night, the whole pla...  2017-01-14 21:20:25
# 4  Pour un restaurant Italien qui pense que Sauce...  2015-06-08 19:09:25

# %% [markdown]
# ## Split test and training set

# %%
def split_data(data, d = 0.75):
    np.random.seed(seed=5)
    mask_test = np.random.rand(data.shape[0]) < d
    return data[mask_test], data[~mask_test]

reviews_training, reviews_test = split_data(reviews, d=0.9)

# %% [markdown]
# ## Pivot a utility table

# %%
def pivot_ratings(df):
    return df.pivot_table(values='stars', columns='user_id', index='business_id')

review_utitity_ratings = pivot_ratings(reviews_training)
display(review_utitity_ratings.head())
# Out:
# user_id                 -01y5njeBMu1eAdIKdGG1g  -0SqALqeWmInVftG_iHcHg  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg                     NaN                     NaN
# -juOL0eJC6kvf5RLEjoPvA                     NaN                     NaN
# -yEFjBrxf2r_BQzRnczzdw                     NaN                     NaN
# 1blpPH0_3jk2EnRz_Q_CuQ                     NaN                     NaN
# 1h3aXVtJLx2o4mArNuhf2w                     NaN                     NaN
#
# user_id                 -41z9zaHp6oONyUNfMDZjw  -5rgQfe0j-0AGl4B9g7DQg  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg                     NaN                     NaN
# -juOL0eJC6kvf5RLEjoPvA                     NaN                     NaN
# user_id                 zhg-j5H6UsCd_DnpvNIprA  zhoytEzEitvTtUfXU99cIA  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg                     NaN                     NaN
# -juOL0eJC6kvf5RLEjoPvA                     1.0                     NaN
# -yEFjBrxf2r_BQzRnczzdw                     NaN                     NaN
# 1blpPH0_3jk2EnRz_Q_CuQ                     NaN                     NaN
# 1h3aXVtJLx2o4mArNuhf2w                     NaN                     NaN
#
# user_id                 zmhC7E1NGHNGf0ITtsxGuw  ztnFttrQ7Rz5neGMcFsXxg
# business_id
# -L9vtxgF0CZ25z-8HqHfDg                     NaN                     NaN
# -juOL0eJC6kvf5RLEjoPvA                     NaN                     NaN
# -yEFjBrxf2r_BQzRnczzdw                     NaN                     NaN
# 1blpPH0_3jk2EnRz_Q_CuQ                     NaN                     NaN
# 1h3aXVtJLx2o4mArNuhf2w                     NaN                     4.0
#
# [5 rows x 854 columns]

# %% [markdown]
# ## Create mean centered simlilarity matrices

# %%
def create_similarity_matrix_cosine(matrix):
    mc_matrix = matrix - matrix.mean(axis = 0)
    return pd.DataFrame(pw.cosine_similarity(mc_matrix.fillna(0)), index = matrix.index, columns = matrix.index)

def create_similarity_matrix_euclidean(matrix):
    mc_matrix = matrix - matrix.mean(axis = 0)
    return pd.DataFrame(pw.euclidean_distances(mc_matrix.fillna(0)), index = matrix.index, columns = matrix.index)

def create_similarity_matrix_polynomial(matrix):
    mc_matrix = matrix - matrix.mean(axis = 0)
    return pd.DataFrame(pw.polynomial_kernel(mc_matrix.fillna(0)), index = matrix.index, columns = matrix.index)

def create_similarity_matrix_sigmoid(matrix):
    mc_matrix = matrix - matrix.mean(axis = 0)
    return pd.DataFrame(pw.sigmoid_kernel(mc_matrix.fillna(0)), index = matrix.index, columns = matrix.index)

# %%
def mean_center_columns(matrix):
    mean_center_columns = matrix.copy()
    for user in mean_center_columns:
        mean_center = mean_center_columns[user].mean()
        for movie in mean_center_columns.index:
            mean_center_columns.at[movie, user] = mean_center_columns.at[movie, user] - mean_center
    return mean_center_columns

# %%
cosine_similarity_ratings = mean_center_columns(create_similarity_matrix_cosine(review_utitity_ratings))
display(cosine_similarity_ratings.head(5))

euclidean_similarity_ratings = mean_center_columns(create_similarity_matrix_euclidean(review_utitity_ratings))
display(euclidean_similarity_ratings.head(5))

polynomial_similarity_ratings = mean_center_columns(create_similarity_matrix_polynomial(review_utitity_ratings))
display(polynomial_similarity_ratings.head(5))

sigmoid_similarity_ratings = mean_center_columns(create_similarity_matrix_sigmoid(review_utitity_ratings))
display(sigmoid_similarity_ratings.head(5))
# Out:
# business_id             -L9vtxgF0CZ25z-8HqHfDg  -juOL0eJC6kvf5RLEjoPvA  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg                0.997879                0.009014
# -juOL0eJC6kvf5RLEjoPvA               -0.002121                1.009014
# -yEFjBrxf2r_BQzRnczzdw               -0.002121               -0.253985
# 1blpPH0_3jk2EnRz_Q_CuQ               -0.002121                0.009014
# -L9vtxgF0CZ25z-8HqHfDg                0.002005               -0.004029
# -juOL0eJC6kvf5RLEjoPvA                0.002005               -0.004029
# -yEFjBrxf2r_BQzRnczzdw                0.002005               -0.004029
# 1blpPH0_3jk2EnRz_Q_CuQ                0.002005               -0.004029
# 1h3aXVtJLx2o4mArNuhf2w                0.002005               -0.004029
#
# business_id             yEzyioaCCZlvlEstY9LNEQ  yYzZScLRg1tNaZZrlz1Z3A  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.004102                0.000539
# -juOL0eJC6kvf5RLEjoPvA               -0.161072                0.000539
# -yEFjBrxf2r_BQzRnczzdw               -0.004102               -0.025330
# 1blpPH0_3jk2EnRz_Q_CuQ                0.406302                0.075717
# 1h3aXVtJLx2o4mArNuhf2w                0.032623               -0.621979
#
# business_id             yvYCSzQm9tjZoBV_gJS7bQ  zHzV2hmXsRYxDNAxvPOVKw
# business_id
# -L9vtxgF0CZ25z-8HqHfDg                0.002072                0.002735
# -juOL0eJC6kvf5RLEjoPvA               -0.004078                0.170806
# -yEFjBrxf2r_BQzRnczzdw                0.009714                0.010207
# 1blpPH0_3jk2EnRz_Q_CuQ                0.037952                0.002735
# 1h3aXVtJLx2o4mArNuhf2w               -0.020076               -0.078100
#
# [5 rows x 177 columns]
# business_id             -L9vtxgF0CZ25z-8HqHfDg  -juOL0eJC6kvf5RLEjoPvA  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -2.234952               -0.249759
# -juOL0eJC6kvf5RLEjoPvA                3.505989               -5.990699
# -yEFjBrxf2r_BQzRnczzdw               -0.348616                0.215480
# 1blpPH0_3jk2EnRz_Q_CuQ               -1.069000               -0.349969
# 1h3aXVtJLx2o4mArNuhf2w                1.126979                0.525773
#
# business_id             -yEFjBrxf2r_BQzRnczzdw  1blpPH0_3jk2EnRz_Q_CuQ  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.595430               -0.724027
# -juOL0eJC6kvf5RLEjoPvA                3.724414                3.750751
# -yEFjBrxf2r_BQzRnczzdw               -2.481766               -0.335081
# 1blpPH0_3jk2EnRz_Q_CuQ               -0.926867               -1.889979
# 1h3aXVtJLx2o4mArNuhf2w                1.034033                1.297814
#
# business_id             1h3aXVtJLx2o4mArNuhf2w  2LRt7Y2-eqpbeDWO2BsPMg  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.403690               -0.512801
# -juOL0eJC6kvf5RLEjoPvA                2.750851                3.400145
# -yEFjBrxf2r_BQzRnczzdw               -0.249822               -0.320062
# 1blpPH0_3jk2EnRz_Q_CuQ               -0.577828               -0.762269
# 1h3aXVtJLx2o4mArNuhf2w               -3.765621                0.829200
#
# business_id             2VAH-mSQXRNpaXysiLtm0Q  2lG2I1LyN6rCiw9U6wKtQg  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.724043               -0.479799
# -juOL0eJC6kvf5RLEjoPvA                3.826269                2.878895
# -yEFjBrxf2r_BQzRnczzdw               -0.327259               -0.281209
# [5 rows x 177 columns]
# business_id             -L9vtxgF0CZ25z-8HqHfDg  -juOL0eJC6kvf5RLEjoPvA  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg            4.397470e-03               -0.000031
# -juOL0eJC6kvf5RLEjoPvA           -6.101296e-08                0.115543
# -yEFjBrxf2r_BQzRnczzdw           -6.101296e-08               -0.007915
# 1blpPH0_3jk2EnRz_Q_CuQ           -6.101296e-08               -0.000031
# 1h3aXVtJLx2o4mArNuhf2w           -6.101296e-08               -0.001266
#
# business_id             -yEFjBrxf2r_BQzRnczzdw  1blpPH0_3jk2EnRz_Q_CuQ  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg           -2.483438e-07           -4.838135e-08
# -juOL0eJC6kvf5RLEjoPvA           -7.883424e-03           -4.838135e-08
# -yEFjBrxf2r_BQzRnczzdw            8.130344e-03           -4.838135e-08
# 1blpPH0_3jk2EnRz_Q_CuQ           -2.483438e-07            3.844662e-04
# 1h3aXVtJLx2o4mArNuhf2w           -2.483438e-07           -4.838135e-08
#
# business_id             1h3aXVtJLx2o4mArNuhf2w  2LRt7Y2-eqpbeDWO2BsPMg  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.000005               -0.000003
# -juOL0eJC6kvf5RLEjoPvA               -0.001240               -0.006520
# -yEFjBrxf2r_BQzRnczzdw               -0.000005                0.000158
# 1blpPH0_3jk2EnRz_Q_CuQ               -0.000005               -0.000003
# 1h3aXVtJLx2o4mArNuhf2w                0.035726                0.000931
#
# business_id             2VAH-mSQXRNpaXysiLtm0Q  2lG2I1LyN6rCiw9U6wKtQg  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg           -3.945773e-08               -0.000004
# -juOL0eJC6kvf5RLEjoPvA           -1.014205e-03                0.003419
# -yEFjBrxf2r_BQzRnczzdw           -3.945773e-08               -0.000004
# 1blpPH0_3jk2EnRz_Q_CuQ           -3.945773e-08               -0.001360
# 1h3aXVtJLx2o4mArNuhf2w           -3.945773e-08               -0.000388
#
# business_id             2nGab5EU6uEmhlI_ovplOw  3M7MWfMh5RSoASV23-6hEw  ...  \
# business_id                                                             ...
# -L9vtxgF0CZ25z-8HqHfDg               -0.000004           -7.735713e-08  ...
# -juOL0eJC6kvf5RLEjoPvA                0.003516           -7.735713e-08  ...
# -yEFjBrxf2r_BQzRnczzdw               -0.000004           -7.735713e-08  ...
# 1blpPH0_3jk2EnRz_Q_CuQ               -0.000004           -7.735713e-08  ...
# 1h3aXVtJLx2o4mArNuhf2w               -0.002328            1.660677e-03  ...
#
# business_id             vHJlN629vOqgI40noEOdlw  xBWn8DSwxzwkWL4JhfzP2g  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.000007               -0.000007
# -juOL0eJC6kvf5RLEjoPvA               -0.031388                0.003599
# -yEFjBrxf2r_BQzRnczzdw               -0.000007               -0.000007
# 1blpPH0_3jk2EnRz_Q_CuQ               -0.000007                0.000919
# 1h3aXVtJLx2o4mArNuhf2w                0.003633               -0.000007
#
# business_id             xLDU3RQ1Ni_wTioEib_VIQ  xMhPyj9NEKEUpcWQMjpqKQ  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg           -9.922608e-07               -0.000002
# -juOL0eJC6kvf5RLEjoPvA           -9.922608e-07               -0.007882
# -yEFjBrxf2r_BQzRnczzdw           -9.922608e-07               -0.000002
# 1blpPH0_3jk2EnRz_Q_CuQ           -9.922608e-07               -0.000002
# 1h3aXVtJLx2o4mArNuhf2w           -9.922608e-07               -0.000002
#
# business_id             xVNdvQQFV7pLfHe6xZ41dQ  yBkgxB_vpwYdsg4WqObRXA  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.000001           -1.190100e-08
# -juOL0eJC6kvf5RLEjoPvA               -0.000001           -1.190100e-08
# -yEFjBrxf2r_BQzRnczzdw               -0.000001           -1.190100e-08
# 1blpPH0_3jk2EnRz_Q_CuQ               -0.000001           -1.190100e-08
# 1h3aXVtJLx2o4mArNuhf2w               -0.000001           -1.190100e-08
#
# business_id             yEzyioaCCZlvlEstY9LNEQ  yYzZScLRg1tNaZZrlz1Z3A  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.000015               -0.000002
# -juOL0eJC6kvf5RLEjoPvA               -0.013133               -0.000002
# -yEFjBrxf2r_BQzRnczzdw               -0.000015               -0.000349
# 1blpPH0_3jk2EnRz_Q_CuQ                0.002010                0.000218
# 1h3aXVtJLx2o4mArNuhf2w                0.001721               -0.017325
#
# business_id             yvYCSzQm9tjZoBV_gJS7bQ  zHzV2hmXsRYxDNAxvPOVKw
# business_id
# -L9vtxgF0CZ25z-8HqHfDg               -0.000009               -0.000009
# -juOL0eJC6kvf5RLEjoPvA               -0.000490                0.013500
# -yEFjBrxf2r_BQzRnczzdw                0.000152                0.000153
# 1blpPH0_3jk2EnRz_Q_CuQ                0.000156               -0.000009
# 1h3aXVtJLx2o4mArNuhf2w               -0.000984               -0.003646
#
# [5 rows x 177 columns]
# business_id             -L9vtxgF0CZ25z-8HqHfDg  -juOL0eJC6kvf5RLEjoPvA  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg            6.140381e-04                0.000003
# -juOL0eJC6kvf5RLEjoPvA            6.503211e-09                0.015161
# -yEFjBrxf2r_BQzRnczzdw            6.503211e-09               -0.001105
# 1blpPH0_3jk2EnRz_Q_CuQ            6.503211e-09                0.000003
# 1h3aXVtJLx2o4mArNuhf2w            6.503211e-09               -0.000170
#
# business_id             -yEFjBrxf2r_BQzRnczzdw  1blpPH0_3jk2EnRz_Q_CuQ  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg            2.647583e-08            5.158287e-09
# -juOL0eJC6kvf5RLEjoPvA           -1.108685e-03            5.158287e-09
# -yEFjBrxf2r_BQzRnczzdw            1.132834e-03            5.158287e-09
# 1blpPH0_3jk2EnRz_Q_CuQ            2.647583e-08            5.382175e-05
# 1h3aXVtJLx2o4mArNuhf2w            2.647583e-08            5.158287e-09
#
# 1blpPH0_3jk2EnRz_Q_CuQ            1.092136e-07            1.268378e-09
# 1h3aXVtJLx2o4mArNuhf2w            1.092136e-07            1.268378e-09
#
# business_id             yEzyioaCCZlvlEstY9LNEQ  yYzZScLRg1tNaZZrlz1Z3A  \
# business_id
# -L9vtxgF0CZ25z-8HqHfDg                0.000002            1.940275e-07
# -juOL0eJC6kvf5RLEjoPvA               -0.001849            1.940275e-07
# -yEFjBrxf2r_BQzRnczzdw                0.000002           -4.838045e-05
# 1blpPH0_3jk2EnRz_Q_CuQ                0.000285            3.092814e-05
# 1h3aXVtJLx2o4mArNuhf2w                0.000244           -2.449811e-03
#
# business_id             yvYCSzQm9tjZoBV_gJS7bQ  zHzV2hmXsRYxDNAxvPOVKw
# business_id
# -L9vtxgF0CZ25z-8HqHfDg            9.412042e-07            9.024019e-07
# -juOL0eJC6kvf5RLEjoPvA           -6.642499e-05            1.877054e-03
# -yEFjBrxf2r_BQzRnczzdw            2.352170e-05            2.348290e-05
# 1blpPH0_3jk2EnRz_Q_CuQ            2.402626e-05            9.024019e-07
# 1h3aXVtJLx2o4mArNuhf2w           -1.356746e-04           -5.093761e-04
#
# [5 rows x 177 columns]

# %% [markdown]
# ## predict ratings

# %%
def predict_ratings(similarity, utility, to_predict):
    ratings_test_c = to_predict.copy()
    ratings_test_c['predicted rating'] = to_predict.apply(lambda row: predict_ids(similarity, utility, row['user_id'], row['business_id']), axis=1)
    return ratings_test_c

def predict_ids(similarity, utility, user_id, business_id):
    if user_id in utility.columns and business_id in similarity.index:
        return predict_vectors(utility.loc[:,user_id], similarity[business_id])
    return 0

def predict_vectors(user_ratings, similarities):
    relevant_ratings = user_ratings.dropna()
    similarities_s = similarities[relevant_ratings.index]
    similarities_s = similarities_s[similarities_s > 0.0]
    relevant_ratings = relevant_ratings[similarities_s.index]
    norm = similarities_s.sum()
    if(norm == 0):
        return 0
    return np.dot(relevant_ratings, similarities_s)/norm

# %%
predicted_item_based_cosine = predict_ratings(cosine_similarity_ratings, review_utitity_ratings, reviews_test[['user_id', 'business_id', 'stars']])
display(predicted_item_based_cosine.head(5))

predicted_item_based_euclidean = predict_ratings(euclidean_similarity_ratings, review_utitity_ratings, reviews_test[['user_id', 'business_id', 'stars']])
display(predicted_item_based_euclidean.head(5))

predicted_item_based_polynomial = predict_ratings(polynomial_similarity_ratings, review_utitity_ratings, reviews_test[['user_id', 'business_id', 'stars']])
display(predicted_item_based_polynomial.head(5))

predicted_item_based_sigmoid = predict_ratings(sigmoid_similarity_ratings, review_utitity_ratings, reviews_test[['user_id', 'business_id', 'stars']])
display(predicted_item_based_sigmoid.head(5))
# Out:
#                    user_id             business_id  stars  predicted rating
# 3   S-t12afI5gGgVWZTV3iQNQ  n2dhdtnOzqeAKSn6s3nQSw    2.0          0.000000
# 27  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    1.0          0.000000
# 28  Umf3Iw_TY-cA6JfyLifYEA  n2dhdtnOzqeAKSn6s3nQSw    4.0          4.000000
# 39  3zdB0SSrXIDIgsrOmhdUtQ  7K9EGbodeoDoOzQvkNPoAw    4.0          4.242116
# 43  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    4.0          0.000000
#                    user_id             business_id  stars  predicted rating
# 3   S-t12afI5gGgVWZTV3iQNQ  n2dhdtnOzqeAKSn6s3nQSw    2.0          0.000000
# 27  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    1.0          0.000000
# 28  Umf3Iw_TY-cA6JfyLifYEA  n2dhdtnOzqeAKSn6s3nQSw    4.0          3.714450
# 39  3zdB0SSrXIDIgsrOmhdUtQ  7K9EGbodeoDoOzQvkNPoAw    4.0          3.826101
# 43  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    4.0          0.000000
#                    user_id             business_id  stars  predicted rating
# 3   S-t12afI5gGgVWZTV3iQNQ  n2dhdtnOzqeAKSn6s3nQSw    2.0          0.000000
# 27  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    1.0          0.000000
# 28  Umf3Iw_TY-cA6JfyLifYEA  n2dhdtnOzqeAKSn6s3nQSw    4.0          4.000000
# 39  3zdB0SSrXIDIgsrOmhdUtQ  7K9EGbodeoDoOzQvkNPoAw    4.0          4.160355
# 43  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    4.0          0.000000
#                    user_id             business_id  stars  predicted rating
# 3   S-t12afI5gGgVWZTV3iQNQ  n2dhdtnOzqeAKSn6s3nQSw    2.0          0.000000
# 27  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    1.0          0.000000
# 28  Umf3Iw_TY-cA6JfyLifYEA  n2dhdtnOzqeAKSn6s3nQSw    4.0          3.999824
# 39  3zdB0SSrXIDIgsrOmhdUtQ  7K9EGbodeoDoOzQvkNPoAw    4.0          4.158452
# 43  i_4JP5Co6WZqgoPHnIPh4g  qxdZWoRVwf4lpI_gjAN2gA    4.0          0.000000

# %% [markdown]
# ## Evaluation

# %%
cosine_median_error = median_absolute_error(predicted_item_based_cosine["stars"], predicted_item_based_cosine["predicted rating"])
euclidean_median_error = median_absolute_error(predicted_item_based_euclidean["stars"], predicted_item_based_euclidean["predicted rating"])
polynomial_median_error = median_absolute_error(predicted_item_based_polynomial["stars"], predicted_item_based_polynomial["predicted rating"])
sigmoid_median_error = median_absolute_error(predicted_item_based_sigmoid["stars"], predicted_item_based_sigmoid["predicted rating"])

# %%
print('                      | median absolute error')
print(f'cosine similarity     |      {cosine_median_error:.2f}')
print(f'euclidean similarity  |      {euclidean_median_error:.2f}')
print(f'polynomial similarity |      {polynomial_median_error:.2f}')
print(f'sigmoid similarity    |      {sigmoid_similarity_ratings:.2f}')
# Out:
#                       | median absolute error
# cosine similarity     |      2.00
# euclidean similarity  |      1.24
# polynomial similarity |      2.00
# sigmoid similarity    |      1.06
